# %% [markdown]
# # Source Separation of the Rhythm Dataset using Spleeter
#
# by:
#
# Estefania Cano
#
# Project ACMUS: https://acmus-mir.github.io/

# %% [markdown]
# ## Install Dependecies

# %%
# !apt install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 14 not upgraded.

# %%
pip install spleeter
# Out:
# ...
#      |████████████████████████████████| 10.5MB 8.3MB/s
# ...
#      |████████████████████████████████| 184kB 41.9MB/s
# ...
#      |████████████████████████████████| 61kB 8.0MB/s
# ...
#   Created wheel for spleeter: filename=spleeter-2.0.1-cp36-none-any.whl size=49679 sha256=5417fd5e88357bfa24ab74e1740906331a0d1726fd602e2addf82ad940346457
#   Stored in directory: /root/.cache/pip/wheels/88/9c/5f/2baad0a9978dd9989fa4f138cc667beca86c2b5f82b9a674a0
# ...
#   Created wheel for librosa: filename=librosa-0.8.0-cp36-none-any.whl size=201376 sha256=43f843079c553bcc134f1a4c715199c901fae9e83dbdce508926c6e5ddb33199
#   Stored in directory: /root/.cache/pip/wheels/ee/10/1e/382bb4369e189938d5c02e06d10c651817da8d485bfd1647c9
# Successfully built spleeter librosa
# ...
#   Found existing installation: pandas 1.1.4
#     Uninstalling pandas-1.1.4:
#       Successfully uninstalled pandas-1.1.4
#   Found existing installation: librosa 0.6.3
#     Uninstalling librosa-0.6.3:
#       Successfully uninstalled librosa-0.6.3
# ...

# %%
from IPython.display import Audio
import os

# %% [markdown]
# ## Separate from command line

# %%
from google.colab import drive
drive.mount('/content/gdrive')
audioDirectory = '/content/gdrive/My Drive/ACMus/Music/DataSet/Rhythmset/Audio'              # Directory in your GDrive where the audio files are saved
outDirectory = '/content/gdrive/My Drive/ACMus/Music/Confidencestudy/separations/rhythm_set/'
# Out:
# Mounted at /content/gdrive

# %%
fileList = os.listdir(audioDirectory)
numFiles = len(fileList)
for file in range(len(fileList)):
  filename = fileList[file]
  filepath = str(os.path.join(audioDirectory,filename))
  print(filepath)
  # !spleeter separate -i '{filepath}' -p spleeter:4stems -o '{outDirectory}'
# Out:
# /content/gdrive/My Drive/ACMus/Music/DataSet/Rhythmset/Audio/rh_0001.wav
# INFO:spleeter:Downloading model archive https://github.com/deezer/spleeter/releases/download/v1.4.0/4stems.tar.gz
# INFO:spleeter:Validating archive checksum
# INFO:spleeter:Extracting downloaded 4stems archive
# INFO:spleeter:4stems model file(s) extracted
# INFO:spleeter:File /content/gdrive/My Drive/ACMus/Music/Confidencestudy/separations/rhythm_set/rh_0001/drums.wav written succesfully
# INFO:spleeter:File /content/gdrive/My Drive/ACMus/Music/Confidencestudy/separations/rhythm_set/rh_0001/vocals.wav written succesfully
# INFO:spleeter:File /content/gdrive/My Drive/ACMus/Music/Confidencestudy/separations/rhythm_set/rh_0001/bass.wav written succesfully
# INFO:spleeter:File /content/gdrive/My Drive/ACMus/Music/Confidencestudy/separations/rhythm_set/rh_0001/other.wav written succesfully
# /content/gdrive/My Drive/ACMus/Music/DataSet/Rhythmset/Audio/rh_0002.wav
# ...
